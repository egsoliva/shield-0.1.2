# %% [markdown]
# ## GPS Accuracy Using Root Mean Squared Error (RMSE)

# %%
from sklearn.metrics import mean_squared_error
import numpy as np
import pandas as pd
import math

data = pd.read_excel('gps_data.xlsx')
lat = data['Latitude']
lon = data['Longitude']
true_lat = data['True Latitude']
true_lon = data['True Longitude']
true_dist, true_dist1, true_dist2, true_dist3 = [], [], [], []
dist1, dist2, dist3 = [], [], []
mse1, mse2, mse3 = [], [], []
loc_rmse = []

dlat = np.deg2rad(lat - true_lat)
dlon = np.deg2rad(lon - true_lon)
lat = np.deg2rad(lat)
lon = np.deg2rad(lon)
true_lat = np.deg2rad(true_lat)
true_lon = np.deg2rad(true_lon)

for i in lat:
    true_dist_value = 0
    true_dist.append(true_dist_value)

# Haversine Formula
rEarth = 6371000
a = (np.sin(dlat / 2) ** 2) + np.cos(true_lat) * np.cos(lat) * ((np.sin(dlon / 2) / 2) ** 2)
c = 2 * np.arcsin(np.sqrt(a))
dist = rEarth * c

# %% [markdown]
# ### First Location (Pililla, Rizal)

# %%
data[0:30]
# Out:
#      Latitude   Longitude  True Latitude  True Longitude         Location
# 0   14.430120  121.337312      14.430289      121.337339  Pililla,  Rizal
# 1   14.430121  121.337312      14.430289      121.337339              NaN
# 2   14.430121  121.337309      14.430289      121.337339              NaN
# 3   14.430124  121.337305      14.430289      121.337339              NaN
# 4   14.430125  121.337304      14.430289      121.337339              NaN
# 5   14.430121  121.337299      14.430289      121.337339              NaN
# 6   14.430120  121.337293      14.430289      121.337339              NaN
# 7   14.430117  121.337290      14.430289      121.337339              NaN
# 8   14.430118  121.337291      14.430289      121.337339              NaN
# 9   14.430119  121.337291      14.430289      121.337339              NaN
# 10  14.430119  121.337289      14.430289      121.337339              NaN
# 11  14.430120  121.337289      14.430289      121.337339              NaN
# ...

# %% [markdown]
# ### First Location RMSE

# %%
dist1 = dist[0:30]
true_dist1 = true_dist[0:30]
mse1 = mean_squared_error(dist1, true_dist1)
rmse = np.sqrt(mse1)
print(rmse)
loc_rmse.append(np.sqrt(mse1))
# Out:
# 18.521240540130293

# %% [markdown]
# ### Second Location (Pineda, Pasig City)

# %%
data[30:60]
# Out:
#      Latitude   Longitude  True Latitude  True Longitude            Location
# 30  14.566052  121.058144       14.56603       121.05823  Pineda, Pasig City
# 31  14.566055  121.058136       14.56603       121.05823                 NaN
# 32  14.566056  121.058136       14.56603       121.05823                 NaN
# 33  14.566058  121.058128       14.56603       121.05823                 NaN
# 34  14.566060  121.058128       14.56603       121.05823                 NaN
# 35  14.566063  121.058121       14.56603       121.05823                 NaN
# 36  14.566065  121.058121       14.56603       121.05823                 NaN
# 37  14.566067  121.058121       14.56603       121.05823                 NaN
# 38  14.566068  121.058121       14.56603       121.05823                 NaN
# 39  14.566068  121.058121       14.56603       121.05823                 NaN
# 40  14.566065  121.058121       14.56603       121.05823                 NaN
# ...

# %% [markdown]
# ### Third Location RMSE

# %%
dist2 = dist[30:60]
true_dist2 = true_dist[30:60]
mse2 = mean_squared_error(dist2, true_dist2)
rmse = np.sqrt(mse2)
print(rmse)
loc_rmse.append(rmse)
# Out:
# 6.791612817518172

# %% [markdown]
# ### Third Location (Greenwoods, Pasig City)

# %%
data[60:90]
# Out:
#      Latitude   Longitude  True Latitude  True Longitude  \
# 60  14.562879  121.098138      14.562817      121.098087
# 61  14.562879  121.098139      14.562817      121.098087
# 62  14.562880  121.098140      14.562817      121.098087
# 63  14.562880  121.098140      14.562817      121.098087
# 64  14.562881  121.098140      14.562817      121.098087
# 65  14.562882  121.098141      14.562817      121.098087
# 66  14.562882  121.098140      14.562817      121.098087
# 67  14.562882  121.098140      14.562817      121.098087
# 68  14.562883  121.098139      14.562817      121.098087
# 69  14.562883  121.098139      14.562817      121.098087
# 70  14.562885  121.098139      14.562817      121.098087
# 71  14.562886  121.098140      14.562817      121.098087
# 72  14.562886  121.098140      14.562817      121.098087
# 73  14.562887  121.098140      14.562817      121.098087
# 74  14.562888  121.098140      14.562817      121.098087
# ...

# %%
dist3 = dist[60:90]
true_dist3 = true_dist[60:90]
mse3 = mean_squared_error(dist3, true_dist3)
rmse = np.sqrt(mse3)
print(rmse)
loc_rmse.append(np.sqrt(mse3))
# Out:
# 8.50024212569389

# %% [markdown]
# ## Remarks (not updated)

# %% [markdown]
# The RMSE serves as a guide to determine the accuracy of a GPS within a specific range. It tells the observer that their true location might be within *n* meters of the true location (*n* is the RMSE).
#
# Based on the data gathered by the researchers, they have noticed that the RMSE calculated on the first location is **18.52 meters**, this suggests that the true value of the coordinate lies within that range. A factor that could have caused the low accuracy are the presence of trees in the area. On the other hand, the accuracy on the second location is within **6.79 meters**. This is a normal range for a low-cost commercial GPS, however, according to the datasheet the NEO-M8N has an accuracy within 2.5 meters (under optimal conditions). It might be good to note that this was tested in a residential area (more reading should be done to understand the reasons why GPS signals are weakened).
